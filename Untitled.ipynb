# %%
import pandas as pd
import sqlalchemy
import numpy as np
import datetime
import re
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
# from six.moves.urllib.request import urlopen
# import urllib
url ="https://docs.google.com/spreadsheets/d/1wzbUySCMjjRdDqBNsoE0byhYplVk8rLbK3Vq0nU0dFQ/export?format=csv&id"
data = pd.read_csv(url, error_bad_lines=False)
data
# Out:
# C:\Users\Dan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        report_date                                   location location_type  \
# 0       2016-03-19                     Argentina-Buenos_Aires      province
# 1       2016-03-19                     Argentina-Buenos_Aires      province
# 2       2016-03-19                     Argentina-Buenos_Aires      province
# 3       2016-03-19                     Argentina-Buenos_Aires      province
# 4       2016-03-19                     Argentina-Buenos_Aires      province
# 5       2016-03-19                     Argentina-Buenos_Aires      province
# 6       2016-03-19                             Argentina-CABA      province
# 7       2016-03-19                             Argentina-CABA      province
# 8       2016-03-19                             Argentina-CABA      province
# 9       2016-03-19                             Argentina-CABA      province
# 10      2016-03-19                             Argentina-CABA      province
# 11      2016-03-19                             Argentina-CABA      province
# 12      2016-03-19                        Argentina-Catamarca      province
# 13      2016-03-19                        Argentina-Catamarca      province
# 14      2016-03-19                        Argentina-Catamarca      province
# 15      2016-03-19                        Argentina-Catamarca      province
# 16      2016-03-19                        Argentina-Catamarca      province
# 17      2016-03-19                        Argentina-Catamarca      province
# 18      2016-03-19                            Argentina-Chaco      province
# 19      2016-03-19                            Argentina-Chaco      province
# 20      2016-03-19                            Argentina-Chaco      province
# 21      2016-03-19                            Argentina-Chaco      province
# 22      2016-03-19                            Argentina-Chaco      province
# 23      2016-03-19                            Argentina-Chaco      province
# 24      2016-03-19                           Argentina-Chubut      province
# 25      2016-03-19                           Argentina-Chubut      province
# 26      2016-03-19                           Argentina-Chubut      province
# 27      2016-03-19                           Argentina-Chubut      province
# 28      2016-03-19                           Argentina-Chubut      province
# 29      2016-03-19                           Argentina-Chubut      province
# ...            ...                                        ...           ...
# 107589  2016-06-21               United_States_Virgin_Islands     territory
# 107590  2016-06-21               United_States_Virgin_Islands     territory
# 107591  2016-06-21               United_States_Virgin_Islands     territory
# 107592  2016-06-28               United_States_Virgin_Islands     territory
# 107593  2016-06-28  United_States_Virgin_Islands-Saint_Thomas        county
# 107594  2016-06-28   United_States_Virgin_Islands-Saint_Croix        county
# 107595  2016-06-28    United_States_Virgin_Islands-Saint_John        county
# 107596  2016-06-28               United_States_Virgin_Islands     territory
# 107597  2016-06-28  United_States_Virgin_Islands-Saint_Thomas        county
# 107598  2016-06-28   United_States_Virgin_Islands-Saint_Croix        county
# 107599  2016-06-28    United_States_Virgin_Islands-Saint_John        county
# 107600  2016-06-28               United_States_Virgin_Islands     territory
# 107601  2016-06-28               United_States_Virgin_Islands     territory
# 107602  2016-06-28               United_States_Virgin_Islands     territory
# 107603  2016-06-28               United_States_Virgin_Islands     territory
# 107604  2016-06-28               United_States_Virgin_Islands     territory
# 107605  2016-06-28               United_States_Virgin_Islands     territory
# 107606  2016-06-28               United_States_Virgin_Islands     territory
# 107607  2016-06-28               United_States_Virgin_Islands     territory
# 107608  2016-06-28               United_States_Virgin_Islands     territory
# 107609  2016-06-28               United_States_Virgin_Islands     territory
# 107610  2016-06-28               United_States_Virgin_Islands     territory
# 107611  2016-06-28               United_States_Virgin_Islands     territory
# 107612  2016-06-28               United_States_Virgin_Islands     territory
# 107613  2016-06-28               United_States_Virgin_Islands     territory
# 107614  2016-06-28               United_States_Virgin_Islands     territory
# 107615  2016-06-28               United_States_Virgin_Islands     territory
# 107616  2016-06-28               United_States_Virgin_Islands     territory
# 107617  2016-06-28               United_States_Virgin_Islands     territory
# 107618  2016-06-28               United_States_Virgin_Islands     territory
#
#                                  data_field data_field_code  time_period  \
# 0          cumulative_confirmed_local_cases          AR0001          NaN
# 1           cumulative_probable_local_cases          AR0002          NaN
# 2       cumulative_confirmed_imported_cases          AR0003          NaN
# 3        cumulative_probable_imported_cases          AR0004          NaN
# 4              cumulative_cases_under_study          AR0005          NaN
# 5                cumulative_cases_discarded          AR0006          NaN
# 6          cumulative_confirmed_local_cases          AR0001          NaN
# 7           cumulative_probable_local_cases          AR0002          NaN
# 8       cumulative_confirmed_imported_cases          AR0003          NaN
# 9        cumulative_probable_imported_cases          AR0004          NaN
# 10             cumulative_cases_under_study          AR0005          NaN
# 11               cumulative_cases_discarded          AR0006          NaN
# 12         cumulative_confirmed_local_cases          AR0001          NaN
# 13          cumulative_probable_local_cases          AR0002          NaN
# 14      cumulative_confirmed_imported_cases          AR0003          NaN
# 15       cumulative_probable_imported_cases          AR0004          NaN
# 16             cumulative_cases_under_study          AR0005          NaN
# 17               cumulative_cases_discarded          AR0006          NaN
# 18         cumulative_confirmed_local_cases          AR0001          NaN
# 19          cumulative_probable_local_cases          AR0002          NaN
# 20      cumulative_confirmed_imported_cases          AR0003          NaN
# 21       cumulative_probable_imported_cases          AR0004          NaN
# 22             cumulative_cases_under_study          AR0005          NaN
# 23               cumulative_cases_discarded          AR0006          NaN
# 24         cumulative_confirmed_local_cases          AR0001          NaN
# 25          cumulative_probable_local_cases          AR0002          NaN
# 26      cumulative_confirmed_imported_cases          AR0003          NaN
# 27       cumulative_probable_imported_cases          AR0004          NaN
# 28             cumulative_cases_under_study          AR0005          NaN
# 29               cumulative_cases_discarded          AR0006          NaN
# ...                                     ...             ...          ...
# 107589                   confirmed_headache          VI0019          NaN
# 107590                    confirmed_malaise          VI0020          NaN
# 107591                     zika_no_specimen          VI0021          NaN
# 107592                        zika_reported          VI0001          NaN
# 107593                        zika_reported          VI0001          NaN
# 107594                        zika_reported          VI0001          NaN
# 107595                        zika_reported          VI0001          NaN
# 107596                    zika_lab_positive          VI0002          NaN
# 107597                    zika_lab_positive          VI0002          NaN
# 107598                    zika_lab_positive          VI0002          NaN
# 107599                    zika_lab_positive          VI0002          NaN
# 107600                             zika_not          VI0003          NaN
# 107601                         zika_pending          VI0004          NaN
# 107602                confirmed_age_under20          VI0005          NaN
# 107603                 confirmed_age_20to39          VI0006          NaN
# 107604                 confirmed_age_40to59          VI0007          NaN
# 107605                 confirmed_age_over59          VI0008          NaN
# 107606                    confirmed_age_unk          VI0009          NaN
# 107607                       confirmed_male          VI0010          NaN
# 107608                     confirmed_female          VI0011          NaN
# 107609                      confirmed_fever          VI0012          NaN
# 107610                confirmed_acute_fever          VI0013          NaN
# 107611                 confirmed_arthralgia          VI0014          NaN
# 107612                  confirmed_arthritis          VI0015          NaN
# 107613                       confirmed_rash          VI0016          NaN
# 107614             confirmed_conjunctivitis          VI0017          NaN
# 107615                    confirmed_eyepain          VI0018          NaN
# 107616                   confirmed_headache          VI0019          NaN
# 107617                    confirmed_malaise          VI0020          NaN
# 107618                     zika_no_specimen          VI0021          NaN
#
#         time_period_type value   unit
# 0                    NaN     0  cases
# 1                    NaN     0  cases
# 2                    NaN     2  cases
# 3                    NaN     1  cases
# 4                    NaN   127  cases
# 5                    NaN     0  cases
# 6                    NaN     0  cases
# 7                    NaN     0  cases
# 8                    NaN     9  cases
# 9                    NaN     0  cases
# 10                   NaN    68  cases
# 11                   NaN     1  cases
# 12                   NaN     0  cases
# 13                   NaN     0  cases
# 14                   NaN     0  cases
# 15                   NaN     0  cases
# 16                   NaN    14  cases
# 17                   NaN     0  cases
# 18                   NaN     0  cases
# 19                   NaN     0  cases
# 20                   NaN     0  cases
# 21                   NaN     0  cases
# 22                   NaN    48  cases
# 23                   NaN     0  cases
# 24                   NaN     0  cases
# 25                   NaN     0  cases
# 26                   NaN     1  cases
# 27                   NaN     0  cases
# 28                   NaN     5  cases
# 29                   NaN     0  cases
# ...                  ...   ...    ...
# 107589               NaN    13  cases
# 107590               NaN     5  cases
# 107591               NaN     3  cases
# 107592               NaN   326  cases
# 107593               NaN   144  cases
# 107594               NaN   173  cases
# 107595               NaN     9  cases
# 107596               NaN    29  cases
# 107597               NaN    12  cases
# 107598               NaN    16  cases
# 107599               NaN     1  cases
# 107600               NaN   252  cases
# 107601               NaN    43  cases
# 107602               NaN     4  cases
# 107603               NaN    12  cases
# 107604               NaN    10  cases
# 107605               NaN     3  cases
# 107606               NaN     0  cases
# 107607               NaN     7  cases
# 107608               NaN    22  cases
# 107609               NaN     2  cases
# 107610               NaN     9  cases
# 107611               NaN    19  cases
# 107612               NaN    13  cases
# 107613               NaN    18  cases
# 107614               NaN     7  cases
# 107615               NaN    13  cases
# 107616               NaN    14  cases
# 107617               NaN     5  cases
# 107618               NaN     2  cases
#
# [107619 rows x 9 columns]

# %%
data_field_filtered= data[data['data_field'].str.contains("confirmed",na=False)]
# data_field_filtered = data[data["data_field"].isin(["cumulative_confirmed_imported_cases","cumulative_confirmed_local_cases"])]
data_field_filtered


# location_filtered
# df = df.loc[~df['Type'].isin(['UnweightedBase', 'Base'])]
# Out:
#        report_date                      location location_type  \
# 0       2016-03-19        Argentina-Buenos_Aires      province
# 2       2016-03-19        Argentina-Buenos_Aires      province
# 6       2016-03-19                Argentina-CABA      province
# 8       2016-03-19                Argentina-CABA      province
# 12      2016-03-19           Argentina-Catamarca      province
# 14      2016-03-19           Argentina-Catamarca      province
# 18      2016-03-19               Argentina-Chaco      province
# 20      2016-03-19               Argentina-Chaco      province
# 24      2016-03-19              Argentina-Chubut      province
# 26      2016-03-19              Argentina-Chubut      province
# 30      2016-03-19             Argentina-Cordoba      province
# 32      2016-03-19             Argentina-Cordoba      province
# 36      2016-03-19          Argentina-Corrientes      province
# 38      2016-03-19          Argentina-Corrientes      province
# 42      2016-03-19          Argentina-Entre_Rios      province
# 44      2016-03-19          Argentina-Entre_Rios      province
# 48      2016-03-19             Argentina-Formosa      province
# 50      2016-03-19             Argentina-Formosa      province
# 54      2016-03-19               Argentina-Jujuy      province
# 56      2016-03-19               Argentina-Jujuy      province
# 60      2016-03-19            Argentina-La_Pampa      province
# 62      2016-03-19            Argentina-La_Pampa      province
# 66      2016-03-19            Argentina-La_Rioja      province
# 68      2016-03-19            Argentina-La_Rioja      province
# 72      2016-03-19             Argentina-Mendoza      province
# 74      2016-03-19             Argentina-Mendoza      province
# 78      2016-03-19            Argentina-Misiones      province
# 80      2016-03-19            Argentina-Misiones      province
# 84      2016-03-19             Argentina-Neuquen      province
# 86      2016-03-19             Argentina-Neuquen      province
# ...            ...                           ...           ...
# 107577  2016-06-21  United_States_Virgin_Islands     territory
# 107578  2016-06-21  United_States_Virgin_Islands     territory
# 107579  2016-06-21  United_States_Virgin_Islands     territory
# 107580  2016-06-21  United_States_Virgin_Islands     territory
# 107581  2016-06-21  United_States_Virgin_Islands     territory
# 107582  2016-06-21  United_States_Virgin_Islands     territory
# 107583  2016-06-21  United_States_Virgin_Islands     territory
# 107584  2016-06-21  United_States_Virgin_Islands     territory
# 107585  2016-06-21  United_States_Virgin_Islands     territory
# 107586  2016-06-21  United_States_Virgin_Islands     territory
# 107587  2016-06-21  United_States_Virgin_Islands     territory
# 107588  2016-06-21  United_States_Virgin_Islands     territory
# 107589  2016-06-21  United_States_Virgin_Islands     territory
# 107590  2016-06-21  United_States_Virgin_Islands     territory
# 107602  2016-06-28  United_States_Virgin_Islands     territory
# 107603  2016-06-28  United_States_Virgin_Islands     territory
# 107604  2016-06-28  United_States_Virgin_Islands     territory
# 107605  2016-06-28  United_States_Virgin_Islands     territory
# 107606  2016-06-28  United_States_Virgin_Islands     territory
# 107607  2016-06-28  United_States_Virgin_Islands     territory
# 107608  2016-06-28  United_States_Virgin_Islands     territory
# 107609  2016-06-28  United_States_Virgin_Islands     territory
# 107610  2016-06-28  United_States_Virgin_Islands     territory
# 107611  2016-06-28  United_States_Virgin_Islands     territory
# 107612  2016-06-28  United_States_Virgin_Islands     territory
# 107613  2016-06-28  United_States_Virgin_Islands     territory
# 107614  2016-06-28  United_States_Virgin_Islands     territory
# 107615  2016-06-28  United_States_Virgin_Islands     territory
# 107616  2016-06-28  United_States_Virgin_Islands     territory
# 107617  2016-06-28  United_States_Virgin_Islands     territory
#
#                                  data_field data_field_code  time_period  \
# 0          cumulative_confirmed_local_cases          AR0001          NaN
# 2       cumulative_confirmed_imported_cases          AR0003          NaN
# 6          cumulative_confirmed_local_cases          AR0001          NaN
# 8       cumulative_confirmed_imported_cases          AR0003          NaN
# 12         cumulative_confirmed_local_cases          AR0001          NaN
# 14      cumulative_confirmed_imported_cases          AR0003          NaN
# 18         cumulative_confirmed_local_cases          AR0001          NaN
# 20      cumulative_confirmed_imported_cases          AR0003          NaN
# 24         cumulative_confirmed_local_cases          AR0001          NaN
# 26      cumulative_confirmed_imported_cases          AR0003          NaN
# 30         cumulative_confirmed_local_cases          AR0001          NaN
# 32      cumulative_confirmed_imported_cases          AR0003          NaN
# 36         cumulative_confirmed_local_cases          AR0001          NaN
# 38      cumulative_confirmed_imported_cases          AR0003          NaN
# 42         cumulative_confirmed_local_cases          AR0001          NaN
# 44      cumulative_confirmed_imported_cases          AR0003          NaN
# 48         cumulative_confirmed_local_cases          AR0001          NaN
# 50      cumulative_confirmed_imported_cases          AR0003          NaN
# 54         cumulative_confirmed_local_cases          AR0001          NaN
# 56      cumulative_confirmed_imported_cases          AR0003          NaN
# 60         cumulative_confirmed_local_cases          AR0001          NaN
# 62      cumulative_confirmed_imported_cases          AR0003          NaN
# 66         cumulative_confirmed_local_cases          AR0001          NaN
# 68      cumulative_confirmed_imported_cases          AR0003          NaN
# 72         cumulative_confirmed_local_cases          AR0001          NaN
# 74      cumulative_confirmed_imported_cases          AR0003          NaN
# 78         cumulative_confirmed_local_cases          AR0001          NaN
# 80      cumulative_confirmed_imported_cases          AR0003          NaN
# 84         cumulative_confirmed_local_cases          AR0001          NaN
# 86      cumulative_confirmed_imported_cases          AR0003          NaN
# ...                                     ...             ...          ...
# 107577                 confirmed_age_40to59          VI0007          NaN
# 107578                 confirmed_age_over59          VI0008          NaN
# 107579                    confirmed_age_unk          VI0009          NaN
# 107580                       confirmed_male          VI0010          NaN
# 107581                     confirmed_female          VI0011          NaN
# 107582                      confirmed_fever          VI0012          NaN
# 107583                confirmed_acute_fever          VI0013          NaN
# 107584                 confirmed_arthralgia          VI0014          NaN
# 107585                  confirmed_arthritis          VI0015          NaN
# 107586                       confirmed_rash          VI0016          NaN
# 107587             confirmed_conjunctivitis          VI0017          NaN
# 107588                    confirmed_eyepain          VI0018          NaN
# 107589                   confirmed_headache          VI0019          NaN
# 107590                    confirmed_malaise          VI0020          NaN
# 107602                confirmed_age_under20          VI0005          NaN
# 107603                 confirmed_age_20to39          VI0006          NaN
# 107604                 confirmed_age_40to59          VI0007          NaN
# 107605                 confirmed_age_over59          VI0008          NaN
# 107606                    confirmed_age_unk          VI0009          NaN
# 107607                       confirmed_male          VI0010          NaN
# 107608                     confirmed_female          VI0011          NaN
# 107609                      confirmed_fever          VI0012          NaN
# 107610                confirmed_acute_fever          VI0013          NaN
# 107611                 confirmed_arthralgia          VI0014          NaN
# 107612                  confirmed_arthritis          VI0015          NaN
# 107613                       confirmed_rash          VI0016          NaN
# 107614             confirmed_conjunctivitis          VI0017          NaN
# 107615                    confirmed_eyepain          VI0018          NaN
# 107616                   confirmed_headache          VI0019          NaN
# 107617                    confirmed_malaise          VI0020          NaN
#
#         time_period_type value   unit
# 0                    NaN     0  cases
# 2                    NaN     2  cases
# 6                    NaN     0  cases
# 8                    NaN     9  cases
# 12                   NaN     0  cases
# 14                   NaN     0  cases
# 18                   NaN     0  cases
# 20                   NaN     0  cases
# 24                   NaN     0  cases
# 26                   NaN     1  cases
# 30                   NaN     1  cases
# 32                   NaN     1  cases
# 36                   NaN     0  cases
# 38                   NaN     2  cases
# 42                   NaN     0  cases
# 44                   NaN     0  cases
# 48                   NaN     0  cases
# 50                   NaN     0  cases
# 54                   NaN     0  cases
# 56                   NaN     0  cases
# 60                   NaN     0  cases
# 62                   NaN     0  cases
# 66                   NaN     0  cases
# 68                   NaN     0  cases
# 72                   NaN     0  cases
# 74                   NaN     1  cases
# 78                   NaN     0  cases
# 80                   NaN     0  cases
# 84                   NaN     0  cases
# 86                   NaN     0  cases
# ...                  ...   ...    ...
# 107577               NaN     9  cases
# 107578               NaN     2  cases
# 107579               NaN     0  cases
# 107580               NaN     8  cases
# 107581               NaN    18  cases
# 107582               NaN     2  cases
# 107583               NaN     8  cases
# 107584               NaN    18  cases
# 107585               NaN    12  cases
# 107586               NaN    17  cases
# 107587               NaN     7  cases
# 107588               NaN    12  cases
# 107589               NaN    13  cases
# 107590               NaN     5  cases
# 107602               NaN     4  cases
# 107603               NaN    12  cases
# 107604               NaN    10  cases
# 107605               NaN     3  cases
# 107606               NaN     0  cases
# 107607               NaN     7  cases
# 107608               NaN    22  cases
# 107609               NaN     2  cases
# 107610               NaN     9  cases
# 107611               NaN    19  cases
# 107612               NaN    13  cases
# 107613               NaN    18  cases
# 107614               NaN     7  cases
# 107615               NaN    13  cases
# 107616               NaN    14  cases
# 107617               NaN     5  cases
#
# [47481 rows x 9 columns]

# %%
# location_group

data_field_filtered["country"]=data["location"]
data_field_filtered["country"]= data["location"].str.split("-", n= 1, expand=True)
                                            
#                                             
# 
data_field_filtered.info()

# data = data.groupby('domain')['ID'].nunique()

# location_filtered = data[data["location_type"]!=["territory","county"]]
# location_filtered

# location_group = zika_df.groupby("location")
# location = pd.DataFrame(location_group)
# location_group = location_group.str.split("-", n = 1, expand = True) 




# 
# print(location.to_string())
# Out:
# C:\Users\Dan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47481 entries, 0 to 107617
# Data columns (total 10 columns):
# report_date         47481 non-null object
# location            47481 non-null object
# location_type       47481 non-null object
# data_field          47481 non-null object
# data_field_code     47481 non-null object
# time_period         0 non-null float64
# time_period_type    0 non-null float64
# value               47469 non-null object
# unit                47481 non-null object
# country             47481 non-null object
# dtypes: float64(2), object(8)
# memory usage: 4.0+ MB
# C:\Users\Dan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#data_field_filtered["value"]=np.where(data_field_filtered["value"]=="NA",0,data_field_filtered["value"])
# data_field_filtered.loc[data_field_filtered["value"]!="NA"]
# data_field_filtered
data_field_filtered1= data_field_filtered[pd.notnull(data_field_filtered["value"])]
# data_field_filtered1.info() 

data_field_filtered1["value1"]= data_field_filtered1["value"].astype("int64")
data_field_filtered1
# calculated the null values
# data_field_filtered1.isnull().sum()

# data_field_filtered1["country"].value_counts()

country_df = data_field_filtered1.groupby('country')["value1"].sum().to_frame().reset_index()

country_df = country_df.rename(columns = {country_df.columns[1]: "comfirmed_cases" })
country_df
# Out:
# C:\Users\Dan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                          country  comfirmed_cases
# 0                      Argentina              665
# 1                         Brazil            25763
# 2                       Colombia           443745
# 3             Dominican_Republic             2447
# 4                        Ecuador             8175
# 5                    El_Salvador              472
# 6                      Guatemala             1578
# 7                         Mexico              565
# 8                      Nicaragua             4704
# 9                         Panama              762
# 10                   Puerto_Rico            44344
# 11  United_States_Virgin_Islands             2000

# %%
country_df.to_json(orient='records')
# Out:
# '[{"country":"Argentina","comfirmed_cases":665},{"country":"Brazil","comfirmed_cases":25763},{"country":"Colombia","comfirmed_cases":443745},{"country":"Dominican_Republic","comfirmed_cases":2447},{"country":"Ecuador","comfirmed_cases":8175},{"country":"El_Salvador","comfirmed_cases":472},{"country":"Guatemala","comfirmed_cases":1578},{"country":"Mexico","comfirmed_cases":565},{"country":"Nicaragua","comfirmed_cases":4704},{"country":"Panama","comfirmed_cases":762},{"country":"Puerto_Rico","comfirmed_cases":44344},{"country":"United_States_Virgin_Islands","comfirmed_cases":2000}]'
